# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
# Out:
# (-1.5839585832348746, 93.85156045445399)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID={weather_api_key}&q="
city_name=[]
lat=[]
lon=[]
max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]

record = 1
group = 1

print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    query_url = url + city
    response = requests.get(query_url).json()
    try:
        print(f"Processing Record {record} of Set {group} | {city}")
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        
        if record > 50:
            record = 1
            group += 1
        else:
            record += 1
    except:
            print("City not found. Skipping...")
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | enid
# Processing Record 3 of Set 1 | huarmey
# Processing Record 4 of Set 1 | hun
# Processing Record 5 of Set 1 | disna
# Processing Record 6 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 1 | krasnoselkup
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | banda aceh
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | saint-leu
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | aksu
# Processing Record 22 of Set 1 | yongan
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | dukat
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | namatanai
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 1 | novo aripuana
# Processing Record 34 of Set 1 | kaabong
# Processing Record 35 of Set 1 | caconda
# Processing Record 36 of Set 1 | varnamo
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | sept-iles
# Processing Record 40 of Set 1 | novikovo
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | paraiso
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | fare
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | vrises
# Processing Record 48 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 1 | nenjiang
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | hilo
# Processing Record 51 of Set 1 | pout
# Processing Record 1 of Set 2 | port hedland
# Processing Record 2 of Set 2 | doha
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 6 of Set 2 | khakhea
# Processing Record 7 of Set 2 | yerbogachen
# Processing Record 8 of Set 2 | balabac
# Processing Record 9 of Set 2 | macomer
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | zemio
# Processing Record 16 of Set 2 | praia da vitoria
# Processing Record 17 of Set 2 | lorengau
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 2 | aleksandrov gay
# Processing Record 20 of Set 2 | gamba
# Processing Record 21 of Set 2 | svencionys
# Processing Record 22 of Set 2 | puerto narino
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | chapleau
# Processing Record 26 of Set 2 | ilinskiy
# Processing Record 27 of Set 2 | riachao das neves
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | rawson
# Processing Record 30 of Set 2 | north bend
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | paragominas
# Processing Record 33 of Set 2 | changqing
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | mehamn
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | martinsburg
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | fairbanks
# Processing Record 43 of Set 2 | los llanos de aridane
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | katubao
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | gazli
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | higuey
# City not found. Skipping...
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | saint anthony
# Processing Record 51 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 51 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 51 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | paamiut
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | santiago del estero
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | wanaka
# Processing Record 7 of Set 3 | pakxan
# Processing Record 8 of Set 3 | umea
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | vicuna
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | punta arenas
# Processing Record 17 of Set 3 | nantucket
# Processing Record 18 of Set 3 | opobo
# City not found. Skipping...
# Processing Record 18 of Set 3 | yar-sale
# Processing Record 19 of Set 3 | rezekne
# Processing Record 20 of Set 3 | narsaq
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | kaset sombun
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | labrea
# Processing Record 27 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 3 | svetlyy
# Processing Record 28 of Set 3 | high river
# Processing Record 29 of Set 3 | kristiinankaupunki
# Processing Record 30 of Set 3 | korla
# Processing Record 31 of Set 3 | port-gentil
# Processing Record 32 of Set 3 | zlatoustovsk
# City not found. Skipping...
# Processing Record 32 of Set 3 | poum
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | celestun
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | coahuayana
# Processing Record 37 of Set 3 | colquechaca
# Processing Record 38 of Set 3 | meulaboh
# Processing Record 39 of Set 3 | abonnema
# Processing Record 40 of Set 3 | san juan
# Processing Record 41 of Set 3 | bikin
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | emba
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | nabire
# Processing Record 46 of Set 3 | inhambane
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | council bluffs
# Processing Record 50 of Set 3 | lamar
# Processing Record 51 of Set 3 | khuzhir
# Processing Record 1 of Set 4 | marand
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | kananga
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | mbuyapey
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | rafaela
# Processing Record 10 of Set 4 | swabi
# Processing Record 11 of Set 4 | axim
# Processing Record 12 of Set 4 | baghdad
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | sakakah
# Processing Record 15 of Set 4 | qurayyat
# Processing Record 16 of Set 4 | patacamaya
# Processing Record 17 of Set 4 | north platte
# Processing Record 18 of Set 4 | scarborough
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | casian
# Processing Record 22 of Set 4 | aklavik
# Processing Record 23 of Set 4 | bara
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | maragogi
# Processing Record 26 of Set 4 | hue
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | cilegon
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | tomatlan
# Processing Record 32 of Set 4 | jiuquan
# Processing Record 33 of Set 4 | bethel
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 4 | san quintin
# Processing Record 37 of Set 4 | riyadh
# Processing Record 38 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 4 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 38 of Set 4 | berberati
# Processing Record 39 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | tilichiki
# Processing Record 40 of Set 4 | salmon creek
# Processing Record 41 of Set 4 | quatre cocos
# Processing Record 42 of Set 4 | obodivka
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | comodoro rivadavia
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | hami
# Processing Record 46 of Set 4 | forotic
# Processing Record 47 of Set 4 | fort nelson
# Processing Record 48 of Set 4 | karatsu
# Processing Record 49 of Set 4 | mahad
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 51 of Set 4 | sanming
# Processing Record 1 of Set 5 | hovd
# Processing Record 2 of Set 5 | tarata
# Processing Record 3 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 5 | diffa
# Processing Record 4 of Set 5 | oussouye
# Processing Record 5 of Set 5 | henties bay
# Processing Record 6 of Set 5 | chernoyerkovskaya
# Processing Record 7 of Set 5 | yukhnov
# Processing Record 8 of Set 5 | torbay
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | la ronge
# Processing Record 11 of Set 5 | nuqui
# Processing Record 12 of Set 5 | hit
# Processing Record 13 of Set 5 | mountain home
# Processing Record 14 of Set 5 | tecoanapa
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | hualmay
# Processing Record 17 of Set 5 | itaituba
# Processing Record 18 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 5 | olinda
# Processing Record 19 of Set 5 | wasilla
# Processing Record 20 of Set 5 | sinnamary
# Processing Record 21 of Set 5 | tocopilla
# Processing Record 22 of Set 5 | birin
# Processing Record 23 of Set 5 | khalastra
# City not found. Skipping...
# Processing Record 23 of Set 5 | leshukonskoye
# Processing Record 24 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | churapcha
# Processing Record 26 of Set 5 | acapulco
# Processing Record 27 of Set 5 | beloha
# Processing Record 28 of Set 5 | santa cruz
# Processing Record 29 of Set 5 | uberaba
# Processing Record 30 of Set 5 | nanortalik
# Processing Record 31 of Set 5 | faya
# Processing Record 32 of Set 5 | zaozerne
# Processing Record 33 of Set 5 | gobabis
# Processing Record 34 of Set 5 | saint-jean-de-maurienne
# Processing Record 35 of Set 5 | atambua
# Processing Record 36 of Set 5 | chapais
# Processing Record 37 of Set 5 | mallasamudram
# Processing Record 38 of Set 5 | quelimane
# Processing Record 39 of Set 5 | yellowknife
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | soe
# Processing Record 42 of Set 5 | bull savanna
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | willowmore
# Processing Record 45 of Set 5 | mattru
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | seoul
# Processing Record 47 of Set 5 | ardakan
# Processing Record 48 of Set 5 | arnedo
# Processing Record 49 of Set 5 | puerto carreno
# Processing Record 50 of Set 5 | codrington
# Processing Record 51 of Set 5 | beni mazar
# Processing Record 1 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 6 | adrar
# Processing Record 2 of Set 6 | puerto escondido
# Processing Record 3 of Set 6 | kentau
# Processing Record 4 of Set 6 | boca do acre
# Processing Record 5 of Set 6 | batagay-alyta
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | serenje
# Processing Record 9 of Set 6 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 9 of Set 6 | imeni poliny osipenko
# Processing Record 10 of Set 6 | okahandja
# Processing Record 11 of Set 6 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | palmer
# Processing Record 14 of Set 6 | piacabucu
# Processing Record 15 of Set 6 | gillette
# Processing Record 16 of Set 6 | carnarvon
# Processing Record 17 of Set 6 | the valley
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | angoche
# Processing Record 20 of Set 6 | nuuk
# Processing Record 21 of Set 6 | nanakuli
# Processing Record 22 of Set 6 | chauk
# Processing Record 23 of Set 6 | sulangan
# Processing Record 24 of Set 6 | beliu
# Processing Record 25 of Set 6 | nichinan
# Processing Record 26 of Set 6 | roebourne
# Processing Record 27 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | thaba nchu
# Processing Record 28 of Set 6 | tiksi
# Processing Record 29 of Set 6 | ikalamavony
# Processing Record 30 of Set 6 | betioky
# Processing Record 31 of Set 6 | stornoway
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | aasiaat
# Processing Record 34 of Set 6 | praia
# Processing Record 35 of Set 6 | iquique
# Processing Record 36 of Set 6 | zabaykalsk
# Processing Record 37 of Set 6 | sault sainte marie
# Processing Record 38 of Set 6 | rio gallegos
# Processing Record 39 of Set 6 | nova petropolis
# Processing Record 40 of Set 6 | krivosheino
# Processing Record 41 of Set 6 | saint-joseph
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | manaure
# Processing Record 44 of Set 6 | nemuro
# Processing Record 45 of Set 6 | male
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | mgandu
# Processing Record 49 of Set 6 | borovichi
# Processing Record 50 of Set 6 | abu zabad
# Processing Record 51 of Set 6 | dargaville
# Processing Record 1 of Set 7 | tonj
# Processing Record 2 of Set 7 | sur
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | zelenoborskiy
# Processing Record 5 of Set 7 | khor
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | kokoda
# Processing Record 9 of Set 7 | rio grande
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | el sauzal
# Processing Record 12 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | acajutla
# Processing Record 14 of Set 7 | ocho rios
# Processing Record 15 of Set 7 | nazarovo
# Processing Record 16 of Set 7 | talaya
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | kemijarvi
# Processing Record 20 of Set 7 | denpasar
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | las tunas
# Processing Record 23 of Set 7 | egvekinot
# Processing Record 24 of Set 7 | biak
# Processing Record 25 of Set 7 | chimbote
# Processing Record 26 of Set 7 | bowen
# Processing Record 27 of Set 7 | flinders
# Processing Record 28 of Set 7 | laguna de perlas
# Processing Record 29 of Set 7 | porto santo
# Processing Record 30 of Set 7 | athabasca
# Processing Record 31 of Set 7 | evensk
# Processing Record 32 of Set 7 | silopi
# Processing Record 33 of Set 7 | upernavik
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | gucheng
# Processing Record 36 of Set 7 | sobolevo
# Processing Record 37 of Set 7 | matara
# Processing Record 38 of Set 7 | sadat
# Processing Record 39 of Set 7 | santa rosa
# Processing Record 40 of Set 7 | crestview
# Processing Record 41 of Set 7 | manado
# Processing Record 42 of Set 7 | camacari
# Processing Record 43 of Set 7 | kattivakkam
# Processing Record 44 of Set 7 | adelanto
# Processing Record 45 of Set 7 | khanpur
# Processing Record 46 of Set 7 | ponta delgada
# Processing Record 47 of Set 7 | rancho palos verdes
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | zhaoyang
# Processing Record 50 of Set 7 | havoysund
# Processing Record 51 of Set 7 | murray bridge
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | togur
# Processing Record 3 of Set 8 | tateyama
# Processing Record 4 of Set 8 | springfield
# Processing Record 5 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 8 | cartagena del chaira
# Processing Record 6 of Set 8 | aquiraz
# Processing Record 7 of Set 8 | paita
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 8 | sibu
# Processing Record 9 of Set 8 | auki
# Processing Record 10 of Set 8 | tiznit
# Processing Record 11 of Set 8 | moree
# Processing Record 12 of Set 8 | cao bang
# Processing Record 13 of Set 8 | mitsamiouli
# Processing Record 14 of Set 8 | montlucon
# Processing Record 15 of Set 8 | durres
# Processing Record 16 of Set 8 | bafq
# Processing Record 17 of Set 8 | shizunai
# Processing Record 18 of Set 8 | save
# Processing Record 19 of Set 8 | awbari
# Processing Record 20 of Set 8 | hot springs
# Processing Record 21 of Set 8 | mackay
# Processing Record 22 of Set 8 | aurdal
# Processing Record 23 of Set 8 | broome
# Processing Record 24 of Set 8 | shache
# Processing Record 25 of Set 8 | alibag
# Processing Record 26 of Set 8 | balsas
# Processing Record 27 of Set 8 | bosaso
# Processing Record 28 of Set 8 | aykino
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | tucuman
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | chernyshevskiy
# Processing Record 33 of Set 8 | komsomolskiy
# Processing Record 34 of Set 8 | senanga
# Processing Record 35 of Set 8 | sao domingos
# Processing Record 36 of Set 8 | ossora
# Processing Record 37 of Set 8 | panguna
# Processing Record 38 of Set 8 | sioux lookout
# Processing Record 39 of Set 8 | sheridan
# Processing Record 40 of Set 8 | pavlivka
# Processing Record 41 of Set 8 | lodja
# Processing Record 42 of Set 8 | honningsvag
# Processing Record 43 of Set 8 | astoria
# Processing Record 44 of Set 8 | cockburn town
# Processing Record 45 of Set 8 | lasa
# Processing Record 46 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 46 of Set 8 | antigua ocotepeque
# Processing Record 47 of Set 8 | xuanhua
# Processing Record 48 of Set 8 | berkovica
# Processing Record 49 of Set 8 | yabrud
# Processing Record 50 of Set 8 | nueva loja
# Processing Record 51 of Set 8 | mount isa
# Processing Record 1 of Set 9 | tarko-sale
# Processing Record 2 of Set 9 | south plainfield
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 9 | erdenet
# Processing Record 5 of Set 9 | ugoofaaru
# Processing Record 6 of Set 9 | pimenteiras
# Processing Record 7 of Set 9 | bulungu
# Processing Record 8 of Set 9 | deputatskiy
# Processing Record 9 of Set 9 | vila
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | lodwar
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | mpika
# Processing Record 14 of Set 9 | yichang
# Processing Record 15 of Set 9 | karaton
# Processing Record 16 of Set 9 | kuito
# Processing Record 17 of Set 9 | gabu
# Processing Record 18 of Set 9 | irbil
# Processing Record 19 of Set 9 | inndyr
# Processing Record 20 of Set 9 | pasighat
# Processing Record 21 of Set 9 | bitkine
# Processing Record 22 of Set 9 | ostersund
# Processing Record 23 of Set 9 | tshikapa
# Processing Record 24 of Set 9 | keetmanshoop
# Processing Record 25 of Set 9 | yaan
# Processing Record 26 of Set 9 | skelleftea
# Processing Record 27 of Set 9 | pangoa
# Processing Record 28 of Set 9 | padre bernardo
# Processing Record 29 of Set 9 | mouila
# Processing Record 30 of Set 9 | horsham
# Processing Record 31 of Set 9 | bonthe
# Processing Record 32 of Set 9 | barguzin
# Processing Record 33 of Set 9 | altrincham
# Processing Record 34 of Set 9 | asosa
# Processing Record 35 of Set 9 | hailar
# Processing Record 36 of Set 9 | ewa beach
# Processing Record 37 of Set 9 | mana
# Processing Record 38 of Set 9 | seydi
# Processing Record 39 of Set 9 | port pirie
# Processing Record 40 of Set 9 | havre-saint-pierre
# Processing Record 41 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 9 | doume
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | tezu
# Processing Record 44 of Set 9 | la crosse
# Processing Record 45 of Set 9 | pithoro
# Processing Record 46 of Set 9 | touros
# Processing Record 47 of Set 9 | portage
# Processing Record 48 of Set 9 | birchis
# Processing Record 49 of Set 9 | chicama
# Processing Record 50 of Set 9 | ternate
# Processing Record 51 of Set 9 | darhan
# Processing Record 1 of Set 10 | valparaiso
# Processing Record 2 of Set 10 | ust-maya
# Processing Record 3 of Set 10 | elmadag
# Processing Record 4 of Set 10 | elko
# Processing Record 5 of Set 10 | mvuma
# Processing Record 6 of Set 10 | manoel urbano
# Processing Record 7 of Set 10 | spencer
# Processing Record 8 of Set 10 | litovko
# Processing Record 9 of Set 10 | kieta
# Processing Record 10 of Set 10 | clyde river
# Processing Record 11 of Set 10 | garissa
# Processing Record 12 of Set 10 | thai nguyen
# Processing Record 13 of Set 10 | runkel
# Processing Record 14 of Set 10 | kungurtug
# Processing Record 15 of Set 10 | sacama
# Processing Record 16 of Set 10 | toamasina
# Processing Record 17 of Set 10 | husavik
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 10 | xai-xai
# Processing Record 19 of Set 10 | kopyevo
# City not found. Skipping...
# Processing Record 19 of Set 10 | kavieng
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | aviles
# Processing Record 21 of Set 10 | mosquera
# Processing Record 22 of Set 10 | pangkalanbuun
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 10 | batemans bay
# Processing Record 25 of Set 10 | manggar
# Processing Record 26 of Set 10 | mount gambier
# Processing Record 27 of Set 10 | selishche
# Processing Record 28 of Set 10 | dzhebariki-khaya
# Processing Record 29 of Set 10 | freeport
# Processing Record 30 of Set 10 | necochea
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | guerrero negro
# Processing Record 33 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 33 of Set 10 | raudeberg
# Processing Record 34 of Set 10 | zharkent
# Processing Record 35 of Set 10 | katsina
# Processing Record 36 of Set 10 | aketi
# Processing Record 37 of Set 10 | iwanai
# Processing Record 38 of Set 10 | valdemarpils
# Processing Record 39 of Set 10 | formosa do rio preto
# Processing Record 40 of Set 10 | dudinka
# Processing Record 41 of Set 10 | zacualpan
# Processing Record 42 of Set 10 | melukote
# Processing Record 43 of Set 10 | alofi
# Processing Record 44 of Set 10 | itoman
# Processing Record 45 of Set 10 | ekhabi
# Processing Record 46 of Set 10 | locri
# Processing Record 47 of Set 10 | strelka
# Processing Record 48 of Set 10 | vysokogornyy
# Processing Record 49 of Set 10 | inuvik
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 51 of Set 10 | gravdal
# Processing Record 1 of Set 11 | lillooet
# Processing Record 2 of Set 11 | rafai
# Processing Record 3 of Set 11 | coos bay
# Processing Record 4 of Set 11 | matagami
# Processing Record 5 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 11 | betlitsa
# Processing Record 6 of Set 11 | brownsville
# Processing Record 7 of Set 11 | bilma
# Processing Record 8 of Set 11 | vestmannaeyjar
# Processing Record 9 of Set 11 | celendin
# Processing Record 10 of Set 11 | susehri
# Processing Record 11 of Set 11 | mareeba
# Processing Record 12 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 11 | turayf
# Processing Record 13 of Set 11 | riverton
# Processing Record 14 of Set 11 | mogadishu
# Processing Record 15 of Set 11 | ornskoldsvik
# Processing Record 16 of Set 11 | mega
# Processing Record 17 of Set 11 | norrtalje
# Processing Record 18 of Set 11 | berezovyy
# Processing Record 19 of Set 11 | ixtapa
# Processing Record 20 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 11 | ust-nera
# Processing Record 21 of Set 11 | kobryn
# Processing Record 22 of Set 11 | sal rei
# Processing Record 23 of Set 11 | palauig
# Processing Record 24 of Set 11 | lambarene
# Processing Record 25 of Set 11 | mulanje
# Processing Record 26 of Set 11 | bardiyah
# Processing Record 27 of Set 11 | marzuq
# Processing Record 28 of Set 11 | altay
# Processing Record 29 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 11 | hanting
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | kenai
# Processing Record 32 of Set 11 | armidale
# Processing Record 33 of Set 11 | nang rong
# Processing Record 34 of Set 11 | nyurba
# Processing Record 35 of Set 11 | wajima
# Processing Record 36 of Set 11 | halifax
# Processing Record 37 of Set 11 | brae
# Processing Record 38 of Set 11 | zaoyang
# Processing Record 39 of Set 11 | gimli
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | anadyr
# Processing Record 42 of Set 11 | usinsk
# Processing Record 43 of Set 11 | orbetello
# Processing Record 44 of Set 11 | mersing
# Processing Record 45 of Set 11 | singaraja
# Processing Record 46 of Set 11 | williams lake
# Processing Record 47 of Set 11 | cienfuegos
# Processing Record 48 of Set 11 | djambala
# Processing Record 49 of Set 11 | leh
# Processing Record 50 of Set 11 | santa maria
# Processing Record 51 of Set 11 | seymchan
# Processing Record 1 of Set 12 | amapa
# Processing Record 2 of Set 12 | yarmouth
# Processing Record 3 of Set 12 | yenagoa
# Processing Record 4 of Set 12 | labuhan
# Processing Record 5 of Set 12 | surskoye
# Processing Record 6 of Set 12 | nome
# Processing Record 7 of Set 12 | irbit
# Processing Record 8 of Set 12 | aanekoski
# Processing Record 9 of Set 12 | benidorm
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({"City": city_name,
                         "Lat": lat,
                         "Lng": lon,
                         "Max Temp": max_temp,
                         "Humidity": humidity,
                         "Cloudiness": cloudiness,
                         "Wind Speed": wind_speed,
                         "Country": country,
                         "Date": date,
                         })

cities_df.to_csv("../output_data/cities.csv", index=True, index_label="City ID", header=True)

cities_df
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     53.60        50          40        6.91
# 1         Enid  36.3956  -97.8784     48.00        87           1        6.91
# 2      Huarmey -10.0681  -78.1522     65.80        85           4        7.72
# 3          Hūn  29.1268   15.9477     78.75        26           0        4.07
# 4        Disna  55.5680   28.1971     57.81        83          17        9.69
# ..         ...      ...       ...       ...       ...         ...         ...
# 565   Surskoye  54.4821   46.7214     65.98        63          70       10.07
# 566       Nome  64.5011 -165.4064     51.01        81           1       14.97
# 567      Irbit  57.6705   63.0710     65.03        46          74        6.17
# 568  Äänekoski  62.6946   25.8180     57.20        67           0        4.61
# 569   Benidorm  38.5382   -0.1310     59.00        50           1        6.64
#
#     Country        Date
# 0        AR  1620793601
# 1        US  1620793807
# 2        PE  1620793808
# 3        LY  1620793808
# 4        BY  1620793809
# ..      ...         ...
# 565      RU  1620794113
# 566      US  1620793959
# 567      RU  1620793935
# 568      FI  1620794113
# 569      ES  1620794114
#
# [570 rows x 9 columns]

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  570.000000  570.000000  570.000000  570.000000  570.000000  570.000000
# mean    20.224476   16.753669   62.490754   69.385965   47.215789    7.313632
# std     33.418165   90.137219   17.395950   21.649918   38.716818    4.902285
# min    -54.800000 -179.166700   17.600000   10.000000    0.000000    0.380000
# 25%     -7.766650  -65.590025   50.400000   57.000000    5.000000    3.537500
# 50%     22.215800   22.075000   62.600000   73.000000   40.000000    6.140000
# 75%     49.145800   96.157150   77.000000   87.000000   90.000000    9.867500
# max     78.218600  178.416700   98.260000  100.000000  100.000000   35.680000
#
#                Date
# count  5.700000e+02
# mean   1.620794e+09
# std    9.017908e+01
# min    1.620794e+09
# 25%    1.620794e+09
# 50%    1.620794e+09
# 75%    1.620794e+09
# max    1.620794e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Cloudiness (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Wind Speed (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_df = cities_df.loc[cities_df["Lat"] >=0,:]
southern_df = cities_df.loc[cities_df["Lat"] <0,:]
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     53.60        50          40
# 2         Huarmey -10.0681  -78.1522     65.80        85           4
# 6           Pisco -13.7000  -76.2167     64.40        82          20
# 7         Rikitea -23.1203 -134.9692     77.99        78          25
# 9    Puerto Ayora  -0.7393  -90.3518     75.99        92          28
# ..            ...      ...       ...       ...       ...         ...
# 549           Vao -22.6667  167.4833     74.91        78          99
# 554     Singaraja  -8.1120  115.0882     86.14        65          42
# 557      Djambala  -2.5447   14.7533     67.66        90           0
# 559   Santa Maria -29.6842  -53.8069     44.60       100           0
# 564       Labuhan  -6.8844  112.2051     87.96        62          55
#
#      Wind Speed Country        Date
# 0          6.91      AR  1620793601
# 2          7.72      PE  1620793808
# 6          2.30      PE  1620793810
# 7         23.58      PF  1620793762
# 9          5.01      EC  1620793811
# ..          ...     ...         ...
# 549       19.60      NC  1620794107
# 554        3.31      ID  1620794109
# 557        1.92      CG  1620794110
# 559        1.14      BR  1620794111
# 564        6.98      ID  1620794112
#
# [181 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Max Temp"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(northern_df["Lat"],northern_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.annotate(line_eq,(1,20), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig5.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is -0.8278867948204613

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Max Temp"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(southern_df["Lat"],southern_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.annotate(line_eq,(-50,80), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig6.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.6110870274020447

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Humidity"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(northern_df["Lat"],northern_df["Humidity"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Humidity (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(45,15), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig7.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.014762660212066256

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Humidity"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(southern_df["Lat"],southern_df["Humidity"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Humidity (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-50,20), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig8.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.21164888518500155

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Cloudiness"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(northern_df["Lat"],northern_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45,35), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig9.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.1134813538912431

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Cloudiness"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(southern_df["Lat"],southern_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-50,55), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig10.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.19281175876792847

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Wind Speed"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,3)) + "x + " + str(round(aa_int,2))


plt.scatter(northern_df["Lat"],northern_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(45,30), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("../output_data/Fig11.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.01877580321773171

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Wind Speed"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))


plt.scatter(southern_df["Lat"],southern_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-50,12), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig("../output_data/Fig12.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is -0.014672003937720867
