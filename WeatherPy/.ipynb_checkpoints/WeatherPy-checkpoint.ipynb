# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 579

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID={weather_api_key}&q="
#Create lists to store data
city_name=[]
lat=[]
lon=[]
max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]

#count the records to not hit the openweather data limit
record = 1
group = 1


#loop through cities and retrieve the relevant info
print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    query_url = url + city
    response = requests.get(query_url).json()
    try:
        print(f"Processing Record {record} of Set {group} | {city}")
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        
        if record > 50:
            record = 1
            group += 1
        else:
            record += 1
    except:
            print("City not found. Skipping...")
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | tongzi
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 1 | xining
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | camacha
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | new glasgow
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | kloulklubed
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | tornio
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | pangkalanbuun
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | sire
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | bardiyah
# Processing Record 25 of Set 1 | havelock
# Processing Record 26 of Set 1 | lompoc
# Processing Record 27 of Set 1 | tromso
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | vynohradove
# Processing Record 30 of Set 1 | pavlodar
# Processing Record 31 of Set 1 | nambour
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | kalispell
# Processing Record 36 of Set 1 | thinadhoo
# Processing Record 37 of Set 1 | san cristobal
# Processing Record 38 of Set 1 | orcotuna
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | burnie
# Processing Record 42 of Set 1 | araouane
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | aykhal
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | leningradskiy
# Processing Record 48 of Set 1 | chattanooga
# Processing Record 49 of Set 1 | sechura
# Processing Record 50 of Set 1 | cidreira
# Processing Record 51 of Set 1 | yar-sale
# Processing Record 1 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | aqtobe
# Processing Record 7 of Set 2 | flinders
# Processing Record 8 of Set 2 | buraydah
# Processing Record 9 of Set 2 | conceicao do araguaia
# Processing Record 10 of Set 2 | ossora
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | luanda
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | portneuf
# Processing Record 18 of Set 2 | severobaykalsk
# Processing Record 19 of Set 2 | rawson
# Processing Record 20 of Set 2 | tautira
# Processing Record 21 of Set 2 | cedar rapids
# Processing Record 22 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | plettenberg bay
# Processing Record 24 of Set 2 | gramalote
# Processing Record 25 of Set 2 | vanimo
# Processing Record 26 of Set 2 | shimanovsk
# Processing Record 27 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | katherine
# Processing Record 31 of Set 2 | piacabucu
# Processing Record 32 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | thayetmyo
# Processing Record 34 of Set 2 | burgeo
# Processing Record 35 of Set 2 | hlotse
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | dwarka
# Processing Record 40 of Set 2 | kabare
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | coihaique
# Processing Record 43 of Set 2 | elbistan
# Processing Record 44 of Set 2 | raudeberg
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | mogadishu
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set
of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 4 | fuerte olimpo
# Processing Record 31 of Set 4 | inhambane
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | peleduy
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | tuatapere
# Processing Record 35 of Set 4 | bay city
# Processing Record 36 of Set 4 | ambon
# Processing Record 37 of Set 4 | ust-koksa
# Processing Record 38 of Set 4 | oktyabrskiy
# Processing Record 39 of Set 4 | san nicolas
# Processing Record 40 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | tucuman
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | qasigiannguit
# Processing Record 43 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 4 | ravenna
# Processing Record 44 of Set 4 | aksarka
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | ilave
# Processing Record 46 of Set 4 | auki
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | buritizeiro
# Processing Record 49 of Set 4 | barcelos
# Processing Record 50 of Set 4 | namwala
# Processing Record 51 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | niort
# Processing Record 2 of Set 5 | la garriga
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | tabory
# Processing Record 5 of Set 5 | haimen
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | yanggu
# Processing Record 9 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 9 of Set 5 | belogorsk
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | airai
# Processing Record 12 of Set 5 | manamadurai
# Processing Record 13 of Set 5 | saint-joseph
# Processing Record 14 of Set 5 | santa marta
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | srednekolymsk
# Processing Record 17 of Set 5 | pijijiapan
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | keuruu
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | damghan
# Processing Record 23 of Set 5 | isiro
# Processing Record 24 of Set 5 | murgab
# Processing Record 25 of Set 5 | almere
# Processing Record 26 of Set 5 | wisconsin rapids
# Processing Record 27 of Set 5 | kinkala
# Processing Record 28 of Set 5 | burica
# City not found. Skipping...
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | kolokani
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | vestmannaeyjar
# Processing Record 34 of Set 5 | lakselv
# Processing Record 35 of Set 5 | celestun
# Processing Record 36 of Set 5 | birao
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | kasongo-lunda
# Processing Record 39 of Set 5 | tocopilla
# Processing Record 40 of Set 5 | vinukonda
# Processing Record 41 of Set 5 | cabra
# Processing Record 42 of Set 5 | mitchell
# Processing Record 43 of Set 5 | palana
# Processing Record 44 of Set 5 | waddan
# Processing Record 45 of Set 5 | luena
# Processing Record 46 of Set 5 | derzhavinsk
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | khabez
# Processing Record 49 of Set 5 | boysun
# Processing Record 50 of Set 5 | dingle
# Processing Record 51 of Set 5 | tomatlan
# Processing Record 1 of Set 6 | port hawkesbury
# Processing Record 2 of Set 6 | mahajanga
# Processing Record 3 of Set 6 | patea
# Processing Record 4 of Set 6 | sangueya
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | altay
# Processing Record 7 of Set 6 | nalut
# Processing Record 8 of Set 6 | kavieng
# Processing Record 9 of Set 6 | campoverde
# Processing Record 10 of Set 6 | grahamstown
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | saint-philippe
# Processing Record 14 of Set 6 | tilichiki
# Processing Record 15 of Set 6 | mitu
# Processing Record 16 of Set 6 | acarau
# Processing Record 17 of Set 6 | kerrville
# Processing Record 18 of Set 6 | scarborough
# Processing Record 19 of Set 6 | bonga
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | baft
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | kimbe
# Processing Record 24 of Set 6 | jaisalmer
# Processing Record 25 of Set 6 | bonfim
# Processing Record 26 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | sao jose da coroa grande
# Processing Record 27 of Set 6 | tateyama
# Processing Record 28 of Set 6 | aksarayskiy
# Processing Record 29 of Set 6 | grand gaube
# Processing Record 30 of Set 6 | fenyi
# Processing Record 31 of Set 6 | sena madureira
# Processing Record 32 of Set 6 | the valley
# Processing Record 33 of Set 6 | listvyanskiy
# Processing Record 34 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | montlucon
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | phulera
# Processing Record 42 of Set 6 | hammerfest
# Processing Record 43 of Set 6 | muros
# Processing Record 44 of Set 6 | el alto
# Processing Record 45 of Set 6 | limbang
# Processing Record 46 of Set 6 | oga
# Processing Record 47 of Set 6 | davila
# Processing Record 48 of Set 6 | nanakuli
# Processing Record 49 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 6 | kabinda
# Processing Record 50 of Set 6 | vostok
# Processing Record 51 of Set 6 | chelno-vershiny
# Processing Record 1 of Set 7 | nehe
# Processing Record 2 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | guaraniacu
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | kenai
# Processing Record 6 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set
of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 10 | is
# City not found. Skipping...
# Processing Record 1 of Set 10 | luganville
# Processing Record 2 of Set 10 | atikokan
# Processing Record 3 of Set 10 | tullahoma
# Processing Record 4 of Set 10 | abhar
# Processing Record 5 of Set 10 | bere
# Processing Record 6 of Set 10 | isangel
# Processing Record 7 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 10 | antofagasta
# Processing Record 8 of Set 10 | lang suan
# Processing Record 9 of Set 10 | kozan
# Processing Record 10 of Set 10 | krasnozatonskiy
# Processing Record 11 of Set 10 | vetovo
# Processing Record 12 of Set 10 | vilhena
# Processing Record 13 of Set 10 | tsiroanomandidy
# Processing Record 14 of Set 10 | angra
# City not found. Skipping...
# Processing Record 14 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | bonthe
# Processing Record 15 of Set 10 | atbasar
# Processing Record 16 of Set 10 | sosnovo-ozerskoye
# Processing Record 17 of Set 10 | birjand
# Processing Record 18 of Set 10 | krasnyy chikoy
# Processing Record 19 of Set 10 | viedma
# Processing Record 20 of Set 10 | roma
# Processing Record 21 of Set 10 | progreso
# Processing Record 22 of Set 10 | magadan
# Processing Record 23 of Set 10 | berlin
# Processing Record 24 of Set 10 | pontes e lacerda
# Processing Record 25 of Set 10 | talaya
# Processing Record 26 of Set 10 | pustoshka
# Processing Record 27 of Set 10 | cordoba
# Processing Record 28 of Set 10 | laguna
# Processing Record 29 of Set 10 | waitati
# Processing Record 30 of Set 10 | boyuibe
# Processing Record 31 of Set 10 | marquette
# Processing Record 32 of Set 10 | beberibe
# Processing Record 33 of Set 10 | lisakovsk
# Processing Record 34 of Set 10 | copiapo
# Processing Record 35 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 10 | nadym
# Processing Record 36 of Set 10 | colomi
# Processing Record 37 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 10 | adrar
# Processing Record 38 of Set 10 | autazes
# Processing Record 39 of Set 10 | gold coast
# Processing Record 40 of Set 10 | matelandia
# Processing Record 41 of Set 10 | soverato
# Processing Record 42 of Set 10 | perth
# Processing Record 43 of Set 10 | danilovka
# Processing Record 44 of Set 10 | port pirie
# Processing Record 45 of Set 10 | estelle
# Processing Record 46 of Set 10 | gallup
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | mount isa
# Processing Record 49 of Set 10 | moree
# Processing Record 50 of Set 10 | saint-georges
# Processing Record 51 of Set 10 | bubaque
# Processing Record 1 of Set 11 | bogandinskiy
# Processing Record 2 of Set 11 | gonbad-e qabus
# Processing Record 3 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | umm kaddadah
# Processing Record 4 of Set 11 | gzhatsk
# City not found. Skipping...
# Processing Record 4 of Set 11 | jiwani
# Processing Record 5 of Set 11 | andra
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | great yarmouth
# Processing Record 8 of Set 11 | kudahuvadhoo
# Processing Record 9 of Set 11 | kotri
# Processing Record 10 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 11 | ancud
# Processing Record 11 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 11 of Set 11 | lakeway
# Processing Record 12 of Set 11 | chara
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | san jose
# Processing Record 15 of Set 11 | prainha
# Processing Record 16 of Set 11 | pochutla
# Processing Record 17 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 17 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 11 | gongzhuling
# Processing Record 18 of Set 11 | simpang
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#move all of the data into a dataframe
cities_df = pd.DataFrame({"City": city_name,
                         "Lat": lat,
                         "Lng": lon,
                         "Max Temp": max_temp,
                         "Humidity": humidity,
                         "Cloudiness": cloudiness,
                         "Wind Speed": wind_speed,
                         "Country": country,
                         "Date": date,
                         })

cities_df.to_csv("cities.csv", index=True, index_label="City ID", header=True)

cities_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura -46.1927  168.8643     39.76        95          92
# 1         Tongzi  28.7829  105.0877     64.63        72         100
# 2         Albany  42.6001  -73.9662     75.00        17          99
# 3         Hobart -42.8794  147.3294     48.20        66          90
# 4        Ushuaia -54.8000  -68.3000     48.20        57          20
# ..           ...      ...       ...       ...       ...         ...
# 523     San Jose  37.3394 -121.8950     68.00        62          75
# 524      Prainha  -1.8000  -53.4800     86.34        59          78
# 525     Pochutla  15.7432  -96.4661     93.20        49          40
# 526  Gongzhuling  43.5008  124.8198     48.34        42          77
# 527      Simpang  -1.2667  104.0833     75.54        97         100
#
#      Wind Speed Country        Date
# 0          3.04      NZ  1621103994
# 1          4.32      CN  1621103994
# 2          2.39      US  1621103757
# 3         10.36      AU  1621103813
# 4         17.27      AR  1621103946
# ..          ...     ...         ...
# 523        3.44      US  1621103940
# 524        2.64      BR  1621104195
# 525       11.50      MX  1621104195
# 526        1.39      CN  1621104196
# 527        2.77      ID  1621104197
#
# [528 rows x 9 columns]

# %%
#Return statistical data
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  528.000000  528.000000  528.000000  528.000000  528.000000  528.000000
# mean    19.180955   17.470368   64.645663   68.293561   55.791667    7.986742
# std     33.921887   90.100017   17.998933   22.004722   39.456244    5.056210
# min    -54.800000 -175.200000    5.970000    7.000000    0.000000    0.340000
# 25%     -9.692525  -61.973525   53.600000   54.750000   16.000000    4.160000
# 50%     22.728800   22.176600   67.120000   73.000000   74.000000    6.910000
# 75%     47.716625   95.218025   78.732500   85.000000   98.000000   10.427500
# max     78.218600  178.416700  100.400000  100.000000  100.000000   28.770000
#
#                Date
# count  5.280000e+02
# mean   1.621104e+09
# std    8.621213e+01
# min    1.621104e+09
# 25%    1.621104e+09
# 50%    1.621104e+09
# 75%    1.621104e+09
# max    1.621104e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#plot latitude vs max temp
plt.scatter(cities_df["Lat"],cities_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#plot latitude vs humidity
plt.scatter(cities_df["Lat"],cities_df["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#plot latitude vs cloudiness
plt.scatter(cities_df["Lat"],cities_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Cloudiness (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#plot latitude vs wind speed
plt.scatter(cities_df["Lat"],cities_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Wind Speed (05/11/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#create DFs for northern and southern hemispheres
northern_df = cities_df.loc[cities_df["Lat"] >=0,:]
southern_df = cities_df.loc[cities_df["Lat"] <0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Max Temp"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs max temp
plt.scatter(northern_df["Lat"],northern_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.annotate(line_eq,(1,20), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig5.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is -0.8312350501539492

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Max Temp"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs max temp
plt.scatter(southern_df["Lat"],southern_df["Max Temp"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Max Temperature (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.annotate(line_eq,(-50,80), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig6.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.7251739028013447

# %% [markdown]
# Both the northern and southern graphs show that there is a correlation between latitude. Since both graphs have their regression lines going through most of the points, there is a strong correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Humidity"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs humidity
plt.scatter(northern_df["Lat"],northern_df["Humidity"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Humidity (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(45,15), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig7.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.09613321163960285

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Humidity"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs humidity
plt.scatter(southern_df["Lat"],southern_df["Humidity"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Humidity (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-50,20), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig8.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.019868263650335588

# %% [markdown]
# Neither the northern not the southern charts provide much insight into whether latitude is related to humidity. Both charts have relatively flat lines, and there are many data points that fall either above or below the line, showing that there is not much correlation.  The southern hemisphere chart shows that it is even less correlated than the northern since the R value is lower.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Cloudiness"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs cloudiness
plt.scatter(northern_df["Lat"],northern_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45,35), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig9.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.1280420308230626

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Cloudiness"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs cloudiness
plt.scatter(southern_df["Lat"],southern_df["Cloudiness"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-50,55), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig10.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is 0.05746606000487415

# %% [markdown]
# Similarly to the humidity graphs, there is not a strong correlation between the cloudiness of a city and it's latitude. Both charts have low R values, which shows that there is not a strong correlation. They both have clusters of data that are above and below the regression line, without many points close to it.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    northern_df["Lat"], northern_df["Wind Speed"])
aa_fit = aa_slope * northern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,3)) + "x + " + str(round(aa_int,2))

#plot latitude vs wind speed
plt.scatter(northern_df["Lat"],northern_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.plot(northern_df["Lat"],aa_fit,"-")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(45,25), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.savefig("Fig11.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is -0.10077779361989982

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#regression calc
aa_slope, aa_int, aa_r, aa_p, aa_std_err = linregress(
    southern_df["Lat"], southern_df["Wind Speed"])
aa_fit = aa_slope * southern_df["Lat"] + aa_int
line_eq = "y = " + str(round(aa_slope,2)) + "x + " + str(round(aa_int,2))

#plot latitude vs wind speed
plt.scatter(southern_df["Lat"],southern_df["Wind Speed"],edgecolors="black",facecolors="blue")
plt.plot(southern_df["Lat"],aa_fit,"-")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed (05/11/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-50,12), fontsize=16,color="firebrick")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

#plt.savefig("Fig12.png")
print(f"The R Value is {aa_r}")
plt.show()
# Out:
# The R Value is -0.07859587080680815

# %% [markdown]
# Similarly to the above charts, besides the max temperature vs latitude chart, there is not a correlation between the wind speed and latitude in neither the southern nor northern hemispheres. Based off this chart and the above, it seems that the only statistic that is correlated, from the data set we pulled, is latitude and max temperature.
